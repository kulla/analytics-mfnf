# %% [markdown]
# # Test APIs
#
# Copyright 2025 Stephan Kulla ("Kulla")
#
# Licensed under the Apache License, Version 2.0 (the "Apache License") and Creative Commons Attribution 4.0 International (the "CC-BY License"). You may choose either of these licenses to govern your use of this project.
#
# You may obtain a copy of the Apache License at:
#     http://www.apache.org/licenses/LICENSE-2.0
#
# You may obtain a copy of the CC-BY License at:
#     https://creativecommons.org/licenses/by/4.0/
#
# Unless required by applicable law or agreed to in writing, software and content distributed under the Apache License is distributed on an "AS IS" BASIS, WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied. See the Apache License for the specific language governing permissions and limitations under the License.
#
# Under the CC-BY License, you are free to share and adapt the material provided you give appropriate credit, provide a link to the license, and indicate if changes were made. See the CC-BY License for full details.
#
# Third-Party Components and Licenses:
# This product also includes third-party components which are distributed under their respective licenses. Please refer to the NOTICE file for details.

# %% [markdown]
# ## Utility functions and imports

# %%
# %load_ext jupyter_ai_magics

# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %% [markdown]
# ## Test new code from the apis

# %%
from wikimedia import WikimediaAPIClient

WikimediaAPIClient().get_edit_comments("Mathe für Nicht-Freaks: Epsilon-Delta-Kriterium der Stetigkeit")
# Out:
# ['/* Übungsaufgaben */',
#  '/* Quadratfunktion */',
#  '/* Beispiel einer stetigen Funktion */ Dativ des Nomens ("Rechteck") zu, mit dem Artikel ("des") korrespondierenden, Genitiv geändert.',
#  'fix typo',
#  '= zu \\le',
#  '/* Motivation */',
#  'Texvc Makros durch LaTeX Pendant ersetzt gemäß [[mw:Extension:Math/Roadmap]]',
#  '/* Verkettete Betragfunktion */ erg',
#  '/* Verkettete Betragfunktion */ Es gibt fälle bei denen gilt 1 < epsilon/15 und damit ist auch delta kleiner als dieser Ausdruck',
#  '/* Unstetigkeit der topologischen Sinusfunktion */Komma hat gefehlt, keine große Sache!',
#  '/* Epsilon-Delta-Kriterium der Stetigkeit */ Formulierung geändert',
#  '/* Epsilon-Delta-Kriterium der Stetigkeit */',
#  'Änderungen von [[Benutzer:Sascha Lill 95|Sascha Lill 95]] ([[Special:Contributions/Sascha Lill 95|Beiträge]]) rückgängig gemacht und letzte Version von [[Benutzer:Stephan Kulla|Stephan Kulla]] wiederhergestellt',
#  '/* Epsilon-Delta-Kriterium impliziert Folgenkriterium */',
#  '/* Epsilon-delta criterion implicates sequence criterion */',
#  '/* Stetigkeit */ fmt',
#  '/* Unstetigkeit der topologischen Sinusfunktion */ typog',
#  '/* Verkettete Betragfunktion */ typo + formatierung "5" -> "5 \\cdot "',
#  '',
#  '/* Epsilon-Delta-Kriterium der Stetigkeit */',
#  '/* Hyperbel */ format',
#  '/* Unstetigkeit */ hier ist UNstetigkeit gemeint oder?',
#  '/* Beispielaufgaben */ Klebstoffsätze entfernt',
#  '/* Erhöhte Anforderungen an die Approximation */ fmt',
#  '/* Stetigkeit bei Approximation von Funktionswerten */  Korrektur gelesen',
#  '/* Unstetigkeit der topologischen Sinusfunktion */',
#  '/* Quadratfunktion */',
#  '/* Stetigkeit bei Approximation von Funktionswerten */',
#  '/* Quadratfunktion */',
#  '/* Beschreibung der Stetigkeit im Graphen */',
#  '/* Epsilon-Delta-Kriterium der Stetigkeit */',
#  '/* Erhöhte Anforderungen an die Approximation */',
#  'review entfernt',
#  '/* Stetigkeit bei Approximation von Funktionswerten */ review',
#  '/* Stetigkeit bei Approximation von Funktionswerten */ review',
#  '/* Stetigkeit bei Approximation von Funktionswerten */',
#  '/* Epsilon-Delta-Kriterium der Stetigkeit */ + [[Vorlage:Noprint]]',
#  '/* Stetigkeit bei Approximation von Funktionswerten */ Einleitung gekürzt',
#  '/* Epsilon-Delta-Kriterium für Unstetigkeit */ üb',
#  '/* Epsilon-Delta-Kriterium der Stetigkeit */ fmt',
#  'Formatierung: Formel-Umgebung sollte nicht mit einem Punkt enden; Format ist {{Formel|<math>...</math>}}',
#  'Mehrfache Leerzeilen entfernt (diese erzeugen im finalen HTML einen leeren Paragraphen)',
#  '/* Epsilon-Delta-Kriterium der Stetigkeit */',
#  '/* Stetigkeit bei Approximation von Funktionswerten */',
#  '/* Stetigkeit bei Approximation von Funktionswerten */',
#  '/* Erhöhte Anforderungen an die Approximation */',
#  '+ titel bei einer Aufgabe',
#  '/* Übungsaufgaben */ Umständlicher Satzbau umformuliert, Kommafehler korrigiert. Der Satz nach der zweiten bearbeiteten Stelle bricht plötzlich ab - mangels Kenntnis der beabsichtigten Aussage konnte ich hier leider keine Korrektur vornehmen.',
#  '/* Abhängigkeiten der Variablen */ einzelner Tippfehler korrigiert',
#  '/* Unstetigkeit der topologischen Sinusfunktion */ Review ergänzt',
#  '/* Erklärungen zum Epsilon-Delta-Kriterium */ Einzelner Kommafehler korrigiert',
#  '/* Motivation */ Einige Grammatikfehler korrigiert, fehlerhafter Einleitungssatz abgeändert (sollte vom ursprünglichen Autor evtl. auf sinngemäße Übereinstimmung mit vorheriger Formulierung überprüft werden)',
#  'Einzelner Rechtschreibfehler korrigiert',
#  '/* Folgenkriterium impliziert Epsilon-Delta-Kriterium */ fmt',
#  '/* Epsilon-Delta-Kriterium impliziert Folgenkriterium */ fmt',
#  '/* Folgenkriterium impliziert Epsilon-Delta-Kriterium */',
#  '/* Epsilon-Delta-Kriterium impliziert Folgenkriterium */',
#  '/* Epsilon-Delta-Kriterium impliziert Folgenkriterium */',
#  '/* Folgenkriterium impliziert Epsilon-Delta-Kriterium */ Kleinere Fehler korrigiert, Wortwiederholung umformuliert, Schreibweise von "sodass" an die im Buch mehrheitlich verwendete Form "so dass" angepasst (Dudenempfehlung wäre jedoch Erstere)',
#  '/* Epsilon-Delta-Kriterium impliziert Folgenkriterium */ unvollständiger Satz korrigiert',
#  '/* Epsilon-Delta-Kriterium der Stetigkeit */ + "\\implies"',
#  '/* Stetigkeit bei Approximation von Funktionswerten */Semantisch unverändert. Fehlende Konjuntion ergänzt, Artikel korrigiert.',
#  '/* Epsilon-Delta-Kriterium der Stetigkeit */',
#  '/* Verkettete Betragfunktion */ üb. siehe: [[Diskussion:Mathe für Nicht-Freaks: Epsilon-Delta-Kriterium der Stetigkeit]]',
#  "/* Verkettete Wurzelfunktion */ Aufgabe von [[Mathe für Nicht-Freaks: Unstetigkeit beweisen: Epsilon-Delta-Kriterium und Folgenkriterium]] hierher kopiert. Autoren: [[Benutzer:Michael D'Erchie]] und [[Benutzer:Stephan Kulla]]",
#  "/* Verkettete Betragfunktion */ Inhalte von [[Mathe für Nicht-Freaks: Stetigkeit beweisen: Epsilon-Delta-Kriterium und Folgenkriterium]] hierher kopiert. Autoren sind [[Benutzer:Michael D'Erchie]] und [[Benutzer:Stephan Kulla]].",
#  "/* Hyperbel */ Inhalte von [[Mathe für Nicht-Freaks: Stetigkeit beweisen: Epsilon-Delta-Kriterium und Folgenkriterium]] hierher kopiert. Autoren sind [[Benutzer:Michael D'Erchie]] und [[Benutzer:Stephan Kulla]].",
#  "/* Quadratfunktion */ Inhalte von [[Mathe für Nicht-Freaks: Stetigkeit beweisen: Epsilon-Delta-Kriterium und Folgenkriterium]] hierher kopiert. Autoren sind [[Benutzer:Michael D'Erchie]] und [[Benutzer:Stephan Kulla]].",
#  '/* Übungsaufgaben */ + Überschriften erstellt',
#  '+ Abschnitt "Übungsaufgaben"',
#  '/* Epsilon-Delta-Kriterium für Unstetigkeit */ kor',
#  '/* Epsilon-Delta-Kriterium für Unstetigkeit */ + <section>',
#  '/* Unstetigkeit */ + <section>',
#  '/* Stetigkeit */ + <section>',
#  '/* Zusammenhang mit dem Folgenkriterium */ fmt',
#  '/* Epsilon-Delta-Kriterium der Stetigkeit */ + <section>',
#  'Stephan Kulla verschob die Seite [[Mathe für Nicht-Freaks: Epsilon-Delta-Definition der Stetigkeit]] nach [[Mathe für Nicht-Freaks: Epsilon-Delta-Kriterium der Stetigkeit]]: besserer Titel',
#  '/* Beispielaufgaben */ Update Link',
#  '/* Zusammenhang mit dem Folgenkriterium */ + <section>',
#  '/* Folgenkriterium impliziert Epsilon-Delta-Kriterium */ üb',
#  '/* Das Folgenkriterium impliziert das Epsilon-Delta-Kriterium */ üb',
#  '/* Das Epsilon-Delta-Kriterium impliziert das Folgenkriterium */ üb',
#  '/* Zusammenhang mit dem Folgenkriterium */ erg',
#  '/* Unstetigkeit */ form',
#  '/* Unstetigkeit */ + Abbildungen',
#  '/* Unstetigkeit */ ergänzt',
#  '/* Stetigkeit */ erg',
#  '/* Stetigkeit */ üb',
#  '/* Stetigkeit */',
#  '/* Stetigkeit */ + Abbildung',
#  '/* Stetigkeit */ erg',
#  '/* Stetigkeit */ + Abbildung',
#  '/* Beispiele */ besserer Titel',
#  '/* Unstetigkeit */ + bessere Abbildung',
#  '/* Unstetigkeit */ üb',
#  '/* Stetigkeit */ üb',
#  '/* Beispiele */ üb: Einleitungssatz',
#  '/* Unstetigkeit */ + Bild; Todo entfernt; üb: Formulierung',
#  '/* Beispiel einer unstetigen Funktion */',
#  '/* Beispiel einer unstetigen Funktion */',
#  '/* Unstetigkeit */',
#  '/* Unstetigkeit */',
#  '/* Stetigkeit */ + Abbildung',
#  '/* Beispiele */ üb',
#  '/* Abhängigkeiten des Deltas */ üb',
#  '/* Beispiel einer unstetigen Funktion */ + Abbildung',
#  '/* Beispiel einer unstetigen Funktion */ üb',
#  '/* Visuelle Interpretation der Epsilon-Delta-Definition im Graphen */ üb und Überschriften ergänzt',
#  '/* Erklärungen zum Epsilon-Delta-Kriterium */ todo entfernt (wird später beschrieben)',
#  '/* Erklärungen zum Epsilon-Delta-Kriterium */ üb',
#  '/* Erklärungen zum Epsilon-Delta-Kriterium */ üb',
#  '/* Erklärungen zum Epsilon-Delta-Kriterium */ formulierung geändert',
#  '/* Erklärungen zum Epsilon-Delta-Kriterium */ restrukturiert',
#  '/* Definition */ + "Epsilon-Delta-Kriterium für Unstetigkeit"',
#  '/* Epsilon-Delta-Kriterium der Stetigkeit */ formulierung im Hinweis geändert',
#  'üb: Motivation',
#  'üb',
#  '/* Visuelle Interpretation der Epsilon-Delta-Definition im Graphen */',
#  '/* Visuelle Interpretation der Epsilon-Delta-Definition im Graphen */',
#  '/* Visuelle Interpretation der Epsilon-Delta-Definition im Graphen */',
#  '/* Visuelle Interpretation der Epsilon-Delta-Definition im Graphen */ Bild Vorzeichenfunktion eingefügt',
#  '/* Visuelle Interpretation der Epsilon-Delta-Definition im Graphen */ + Abbildungen',
#  '/* Visuelle Interpretation der Epsilon-Delta-Definition im Graphen */ + Bilder',
#  '/* Visuelle Interpretation der Epsilon-Delta-Definition im Graphen */ erg',
#  '/* Visuelle Interpretation der Epsilon-Delta-Definition im Graphen */ erg',
#  '/* Definition */',
#  '/* Abhängigkeiten des Deltas */',
#  '/* Abhängigkeiten des Deltas */',
#  'Version 808710 von [[Spezial:Contributions/80.109.67.43|80.109.67.43]] ([[Benutzer Diskussion:80.109.67.43]]) wurde entfernt. Link falsch gesetzt.',
#  '/* Das Epsilon-Delta-Kriterium aufgefasst als Spiel */',
#  '/* Zusammenhang mit dem Folgenkriterium */',
#  '/* Zusammenhang mit dem Folgenkriterium */',
#  '/* Zusammenhang mit dem Folgenkriterium */',
#  '/* Epsilon-Delta-Kriterium der Stetigkeit */',
#  '/* Epsilon-Delta-Kriterium der Stetigkeit */Tippfehler korrigiert',
#  '/* Stetigkeit bei Approximation von Funktionswerten */Tippfehler korrigiert',
#  '/* Stetigkeit bei Approximation von Funktionswerten */Tippfehler korrigiert',
#  '/* Zusammenhang mit dem Folgenkriterium */ typo',
#  '/* Beispiele */ + todos',
#  '/* Beispiele */ todo gesetzt',
#  '',
#  '/* Zusammenhang mit dem Folgenkriterium */',
#  '/* Zusammenhang mit dem Folgenkriterium */',
#  '/* Zusammenhang mit dem Folgenkriterium */',
#  '/* Zusammenhang mit dem Folgenkriterium */',
#  '/* Beispiel für Unstetigkeit */',
#  '/* Beispiel für Unstetigkeit */',
#  '/* Beispiel für Stetigkeit */',
#  '/* Beispiel für Stetigkeit */',
#  '/* Beispiel für Stetigkeit */',
#  '/* Abhängigkeiten des Deltas */',
#  '/* Erhöhte Anforderungen an die Approximation */',
#  '+ Abschnitt "Abhängigkeiten des Deltas"',
#  '/* Definition */ erg',
#  'Bilder skaliert',
#  '/* Epsilon-Delta-Kriterium der Stetigkeit */',
#  '/* Epsilon-Delta-Kriterium der Stetigkeit */ + Abbildungen',
#  '/* Erhöhte Anforderungen an die Approximation */ + Abbildungen',
#  '/* Stetigkeit bei Approximation von Funktionswerten */ + Abbildungen',
#  '/* Erhöhte Anforderungen an die Approximation */ typo',
#  '/* Stetigkeit bei Approximation von Funktionswerten */ erg',
#  '/* Stetigkeit bei Approximation von Funktionswerten */ erg',
#  '+ "Zusammenhang mit dem Folgenkriterium"',
#  '/* Intuition der Epsilon-Delta-Definition */ üb',
#  '/* Intuition der Epsilon-Delta-Definition */ üb',
#  '/* Stetigkeit bei Approximation von Funktionswerten */ typo',
#  '/* Epsilon-Delta-Kriterium der Stetigkeit */ erg',
#  '"\\tilde x" -> "x_0"',
#  'erg',
#  '/* Definition */ üb',
#  '/* Intuition der Epsilon-Delta-Definition */ fmt',
#  '/* Visuelle Interpretation der Epsilon-Delta-Definition im Graphen */ fmt',
#  '/* Motivation */ erg',
#  '/* Motivation */ Zwischenspeicherung (mache später weiter)',
#  '/* Motivation */ erg',
#  'erg + üb (Einleitung)',
#  '/* Die Epsilon-Delta-Definition */ typo',
#  '/* Beispiel */',
#  '',
#  '/* Intuition der Epsilon-Delta-Definition */',
#  '/* Die Epsilon-Delta-Definition */',
#  '/* Die Epsilon-Delta-Definition */',
#  '/* Die Epsilon-Delta-Definition */',
#  '/* Die Epsilon-Delta-Definition */ erg: D\\subseteq \\R',
#  '/* Intuition der Epsilon-Delta-Definition */ fmt',
#  '/* Intuition der Epsilon-Delta-Definition */ fmt',
#  '/* Intuition der Epsilon-Delta-Definition */',
#  '/* Die Epsilon-Delta-Definition */',
#  '/* Die Epsilon-Delta-Definition */ typo',
#  'Neue Seite (vgl. [[WB:AZ]])']

# %%
from diskcache import Cache

# %%
from mfnf import MFNF

WikimediaAPIClient().get_pageviews("Mathe für Nicht-Freaks")
# Out:
# [('20160101', 117),
#  ('20160102', 258),
#  ('20160103', 218),
#  ('20160104', 187),
#  ('20160105', 166),
#  ('20160106', 204),
#  ('20160107', 151),
#  ('20160108', 134),
#  ('20160109', 137),
#  ('20160110', 168),
#  ('20160111', 178),
#  ('20160112', 178),
#  ('20160113', 181),
#  ('20160114', 184),
#  ('20160115', 152),
#  ('20160116', 109),
#  ('20160117', 154),
#  ('20160118', 200),
#  ('20160119', 144),
#  ('20160120', 321),
#  ('20160121', 155),
#  ('20160122', 120),
#  ('20160123', 125),
#  ('20160124', 149),
#  ('20160125', 194),
#  ('20160126', 173),
#  ('20160127', 155),
#  ('20160128', 156),
#  ('20160129', 153),
#  ('20160130', 107),
#  ('20160131', 155),
#  ('20180624', 136),
#  ('20180625', 154),
#  ('20180626', 150),
#  ('20180627', 85),
#  ('20180628', 127),
#  ('20180629', 82),
#  ('20180630', 100),
#  ('20180701', 106),
#  ('20180702', 141),
#  ('20180703', 133),
#  ('20180704', 129),
#  ('20180705', 128),
#  ('20180706', 132),
#  ('20180707', 108),
#  ('20180708', 87),
#  ('20180709', 113),
#  ('20180710', 137),
#  ('20180711', 110),
#  ('20180712', 112),
#  ('20180713', 100),
#  ('20180714', 73),
#  ('20180715', 105),
#  ('20180716', 131),
#  ('20180717', 99),
#  ('20180718', 98),
#  ('20180719', 95),
#  ('20180720', 77),
#  ('20180721', 127),
#  ('20180722', 89),
#  ('20180723', 125),
#  ('20180724', 95),
#  ('20180725', 93),
#  ('20180726', 226),
#  ('20180727', 112),
#  ('20180728', 98),
#  ('20180729', 149),
#  ('20180730', 112),
#  ('20180731', 135),
#  ('20180801', 119),
#  ('20180802', 120),
#  ('20180803', 85),
#  ('20180804', 94),
#  ('20180805', 86),
#  ('20180806', 119),
#  ('20180807', 148),
#  ('20180808', 131),
#  ('20180809', 147),
#  ('20180810', 122),
#  ('20180811', 108),
#  ('20180812', 134),
#  ('20180813', 131),
#  ('20180814', 143),
#  ('20180815', 123),
#  ('20180816', 119),
#  ('20180817', 107),
#  ('20180818', 98),
#  ('20180819', 86),
#  ('20180820', 100),
#  ('20180821', 130),
#  ('20180822', 98),
#  ('20180823', 140),
#  ('20180824', 102),
#  ('20180825', 83),
#  ('20180826', 75),
#  ('20180827', 90),
#  ('20180828', 99),
#  ('20180829', 110),
#  ('20180830', 191),
#  ('20180831', 94),
#  ('20180901', 103),
#  ('20180902', 111),
#  ('20180903', 125),
#  ('20180904', 123),
#  ('20180905', 141),
#  ('20180906', 131),
#  ('20180907', 141),
#  ('20180908', 85),
#  ('20180909', 66),
#  ('20180910', 118),
#  ('20180911', 134),
#  ('20180912', 156),
#  ('20180913', 120),
#  ('20180914', 108),
#  ('20180915', 121),
#  ('20180916', 134),
#  ('20180917', 119),
#  ('20180918', 204),
#  ('20180919', 159),
#  ('20180920', 125),
#  ('20180921', 92),
#  ('20180922', 110),
#  ('20180923', 131),
#  ('20180924', 118),
#  ('20180925', 126),
#  ('20180926', 159),
#  ...]

# %%
# %time MFNF().aggregate_pageviews()
# Out:
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# File ~/workspace/kulla/analytics-mfnf/.venv/lib/python3.13/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# File ~/workspace/kulla/analytics-mfnf/.venv/lib/python3.13/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#
# File ~/workspace/kulla/analytics-mfnf/.venv/lib/python3.13/site-packages/urllib3/connection.py:516, in HTTPConnection.getresponse(self)
#     515 # Get the response from http.client.HTTPConnection
# --> 516 httplib_response = super().getresponse()
#     518 try:
#
# File ~/.local/share/uv/python/cpython-3.13.2-linux-x86_64-gnu/lib/python3.13/http/client.py:1430, in HTTPConnection.getresponse(self)
#    1429 try:
# -> 1430     response.begin()
#    1431 except ConnectionError:
#
# File ~/.local/share/uv/python/cpython-3.13.2-linux-x86_64-gnu/lib/python3.13/http/client.py:331, in HTTPResponse.begin(self)
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#
# File ~/.local/share/uv/python/cpython-3.13.2-linux-x86_64-gnu/lib/python3.13/http/client.py:300, in HTTPResponse._read_status(self)
#     297 if not line:
#     298     # Presumably, the server closed the connection before
#     299     # sending a valid response.
# --> 300     raise RemoteDisconnected("Remote end closed connection without"
#     301                              " response")
#     302 try:
#
# RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# File ~/workspace/kulla/analytics-mfnf/.venv/lib/python3.13/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File ~/workspace/kulla/analytics-mfnf/.venv/lib/python3.13/site-packages/urllib3/connectionpool.py:841, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     839     new_e = ProtocolError("Connection aborted.", new_e)
# --> 841 retries = retries.increment(
#     842     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     843 )
#     844 retries.sleep()
#
# File ~/workspace/kulla/analytics-mfnf/.venv/lib/python3.13/site-packages/urllib3/util/retry.py:474, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     473 if read is False or method is None or not self._is_method_retryable(method):
# --> 474     raise reraise(type(error), error, _stacktrace)
#     475 elif read is not None:
#
# File ~/workspace/kulla/analytics-mfnf/.venv/lib/python3.13/site-packages/urllib3/util/util.py:38, in reraise(tp, value, tb)
#      37 if value.__traceback__ is not tb:
# ---> 38     raise value.with_traceback(tb)
#      39 raise value
#
# File ~/workspace/kulla/analytics-mfnf/.venv/lib/python3.13/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# File ~/workspace/kulla/analytics-mfnf/.venv/lib/python3.13/site-packages/urllib3/connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#
# File ~/workspace/kulla/analytics-mfnf/.venv/lib/python3.13/site-packages/urllib3/connection.py:516, in HTTPConnection.getresponse(self)
#     515 # Get the response from http.client.HTTPConnection
# --> 516 httplib_response = super().getresponse()
#     518 try:
#
# File ~/.local/share/uv/python/cpython-3.13.2-linux-x86_64-gnu/lib/python3.13/http/client.py:1430, in HTTPConnection.getresponse(self)
#    1429 try:
# -> 1430     response.begin()
#    1431 except ConnectionError:
#
# File ~/.local/share/uv/python/cpython-3.13.2-linux-x86_64-gnu/lib/python3.13/http/client.py:331, in HTTPResponse.begin(self)
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#
# File ~/.local/share/uv/python/cpython-3.13.2-linux-x86_64-gnu/lib/python3.13/http/client.py:300, in HTTPResponse._read_status(self)
#     297 if not line:
#     298     # Presumably, the server closed the connection before
#     299     # sending a valid response.
# --> 300     raise RemoteDisconnected("Remote end closed connection without"
#     301                              " response")
#     302 try:
#
# ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# File <timed eval>:1
#
# File <string>:27, in aggregate_pageviews(self)
#
# File ~/workspace/kulla/analytics-mfnf/.venv/lib/python3.13/site-packages/pandas/core/frame.py:2461, in DataFrame.from_records(cls, data, index, exclude, columns, coerce_float, nrows)
#    2458 values = [first_row]
#    2460 if nrows is None:
# -> 2461     values += data
#    2462 else:
#    2463     values.extend(itertools.islice(data, nrows - 1))
#
# File <string>:26, in get_rows()
#
# File <string>:13, in get_pageview_rows(target_title, book, section, page)
#
# File ~/workspace/kulla/analytics-mfnf/wikimedia.py:27, in WikimediaAPIClient.get_pageviews(self, page_title)
#      24 page_title = quote(page_title, safe="")
#      25 api_url = f"https://wikimedia.org/api/rest_v1/metrics/pageviews/per-article/{self.domain}/all-access/all-agents/{page_title}/daily/{start_date}/{end_date}"
# ---> 27 response = self.http_client.get(api_url)
#      29 if response.status_code == 404:
#      30     return []
#
# File ~/workspace/kulla/analytics-mfnf/.venv/lib/python3.13/site-packages/requests/sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File ~/workspace/kulla/analytics-mfnf/.venv/lib/python3.13/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/workspace/kulla/analytics-mfnf/.venv/lib/python3.13/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/workspace/kulla/analytics-mfnf/.venv/lib/python3.13/site-packages/requests/adapters.py:682, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#    (...)    678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
# --> 682     raise ConnectionError(err, request=request)
#     684 except MaxRetryError as e:
#     685     if isinstance(e.reason, ConnectTimeoutError):
#     686         # TODO: Remove this in 3.0.0: see #2811
#
# ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
