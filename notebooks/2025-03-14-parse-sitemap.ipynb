# %% [markdown]
# # Parse sitemap
#
# Copyright 2025 Stephan Kulla ("Kulla")
#
# Licensed under the Apache License, Version 2.0 (the "Apache License") and Creative Commons Attribution 4.0 International (the "CC-BY License"). You may choose either of these licenses to govern your use of this project.
#
# You may obtain a copy of the Apache License at:
#     http://www.apache.org/licenses/LICENSE-2.0
#
# You may obtain a copy of the CC-BY License at:
#     https://creativecommons.org/licenses/by/4.0/
#
# Unless required by applicable law or agreed to in writing, software and content distributed under the Apache License is distributed on an "AS IS" BASIS, WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied. See the Apache License for the specific language governing permissions and limitations under the License.
#
# Under the CC-BY License, you are free to share and adapt the material provided you give appropriate credit, provide a link to the license, and indicate if changes were made. See the CC-BY License for full details.
#
# Third-Party Components and Licenses:
# This product also includes third-party components which are distributed under their respective licenses. Please refer to the NOTICE file for details.

# %% [markdown]
# ## Utility functions and imports

# %%
# %load_ext jupyter_ai_magics

# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %% [markdown]
# ## Helper function to download wikitext

# %%
import requests

def get_wikitext(page_title):
    url = 'https://de.wikibooks.org/w/api.php'
    
    params = {
        'action': 'query',
        'format': 'json',
        'prop': 'revisions',
        'titles': page_title,
        'rvprop': 'content',
        'rvslots': '*'
    }

    response = requests.get(url, params=params)
    
    if response.status_code != 200:
        raise Exception(f"Error fetching data: {response.status_code}")
    
    data = response.json()
    pages = data['query']['pages']

    for page_id, page in pages.items():
        if 'revisions' in page:
            wikitext = page['revisions'][0]['slots']['main']['*']
            return wikitext

    raise ValueError(f"No content found for page: {page_title}")

# Example usage
page_title = 'Mathe für Nicht-Freaks: Analysis 1'
try:
    wikitext = get_wikitext(page_title)
    print(wikitext)
except Exception as e:
    print(e)
# Out:
# {{#invoke:Mathe für Nicht-Freaks/Seite|oben}}
#
# {{#invoke:Mathe für Nicht-Freaks/Seite|unten}}

# %% [markdown]
# ## Download sitemap

# %%
raw_sitemap = get_wikitext("Mathe für Nicht-Freaks: Sitemap")

# Print first 50 lines
print("\n".join(raw_sitemap.split("\n")[0:50]))
# Out:
# {{#invoke:Mathe für Nicht-Freaks/Seite|oben}}
#
# Diese Seite listet alle Kapitel des Projekts „Mathe für Nicht-Freaks“ auf. Diese Seite dient zur Übersicht und aus ihr werden die komplette Navigation und die Inhaltsverzeichnisse der einzelnen Bücher generiert.
#
# {| class="wikitable"
# |+ Legende
# ! Symbol
# ! Bedeutung
# |-
# | <span style="color:#BA0000;">roter Link</span>
# | Link auf ein Kapitel, welches noch nicht existiert und welches noch geschrieben werden muss.
# |-
# | <span style="color:#0645AD;">blauer Link</span>
# | Kapitel wurde bereits angelegt und enthält Inhalt.
# |-
# | {{Symbol|0%}}
# | Fortschritt 0% – Kapitel besitzt keinen oder kaum Inhalt. Das Kapitel muss neu geschrieben bzw. ergänzt und überarbeitet werden.
# |-
# | {{Symbol|25%}}
# | Fortschritt 25% – Kapitel befindet sich in der Entwicklung, muss aber noch wesentlich ergänzt werden.
# |-
# | {{Symbol|50%}}
# | Fortschritt 50% – Wesentliche Inhalte sind vorhanden, es müssen aber noch wichtige Inhalte hinzugefügt werden (oft befinden sich auf der Seite ToDo-Hinweise, was noch ergänzt werden muss).
# |-
# | {{Symbol|75%}}
# | Fortschritt 75% – Kapitel ist inhaltlich fertig, muss aber noch überarbeitet werden (Korrektur von Rechtschreibfehlern, Formulierungen so verändern, dass sie verständlicher sind oder besser klingen. Unnötige und unpassende Füllwörter wie „auch“ entfernen).
# |-
# | {{Symbol|100%}}
# | Fortschritt 100% – Kapitel ist inhaltlich fertig und wurde mindestens einmal Korrektur gelesen. Aber auch diese Kapitel kannst du Korrektur lesen. Sprich: Rechtschreibfehler korrigieren und Formulierungen verbessern. Auch diese Kapitel können (wie alle anderen) inhaltlich ergänzt werden.
# |}
#
# == [[Mathe für Nicht-Freaks: Grundlagen der Mathematik|Grundlagen der Mathematik]] ==
#
# === Was ist Mathematik? ===
# * [[Mathe für Nicht-Freaks: Was ist Mathematik?|Was ist Mathematik?]] {{Symbol|100%}}
#
# === Einführung in die Logik ===
# * [[Mathe für Nicht-Freaks: Logik und Aussagen|Logik und Aussagen]] {{Symbol|100%}}
# * [[Mathe für Nicht-Freaks: Junktor|Junktoren]] {{Symbol|100%}}
# * [[Mathe für Nicht-Freaks: Aussagenlogik|Aussagenlogik]] {{Symbol|75%}}
# * [[Mathe für Nicht-Freaks: Wahrheitstabelle|Wahrheitstabelle]] {{Symbol|75%}}
# * [[Mathe für Nicht-Freaks: Tautologie|Tautologien]] {{Symbol|100%}}
# * [[Mathe für Nicht-Freaks: Quantor|Quantoren]] {{Symbol|100%}}
# * [[Mathe für Nicht-Freaks: Aussageform und Substitution|Aussageform und Substitution]] {{Symbol|100%}}
# * [[Mathe für Nicht-Freaks: Prädikatenlogik|Prädikatenlogik]] {{Symbol|0%}}
# * [[Mathe für Nicht-Freaks: Aussagen formalisieren|Aussagen formalisieren]] {{Symbol|75%}}
# * [[Mathe für Nicht-Freaks: Aussagen negieren|Aussagen negieren]] {{Symbol|100%}}
# * [[Mathe für Nicht-Freaks: Klassenlogik|Klassenlogik]] {{Symbol|0%}}
# * [[Mathe für Nicht-Freaks: Gesetze der Logik|Gesetze der Logik]] {{Symbol|100%}}
# * [[Mathe für Nicht-Freaks: Aufgaben zur Logik|Aufgaben]]

# %% [markdown]
# ## Parse sitemap

# %%
import json

from dataclasses import dataclass, asdict, field
from typing import List, Literal


@dataclass
class BookLine:
    name: str
    href: str


@dataclass
class SectionLine:
    name: str


@dataclass
class PageLine:
    name: str
    href: str


def parse_link(line):
    end_index = line.find("]]")

    if line.startswith("[[") and end_index > 2:
        link_content = line[2:end_index]
        link_parts = link_content.split("|")

        if len(link_parts) == 2:
            return link_parts

    return (None, None)


def parse_sitemap_line(sitemap_line):
    if sitemap_line.startswith("===") and sitemap_line.endswith("==="):
        name = sitemap_line.strip("===").strip()

        if name:
            return SectionLine(name)
    elif sitemap_line.startswith("==") and sitemap_line.endswith("=="):
        href, name = parse_link(sitemap_line.strip("==").strip())

        if href and name:
            return BookLine(name, href)
    elif sitemap_line.startswith("* "):
        href, name = parse_link(sitemap_line.lstrip("* "))

        if href and name:
            return PageLine(name, href)
            
    return None


@dataclass
class Project:
    kind: Literal["project"] = "project"
    name: Literal["Mathe für Nicht-Freaks"] = "Mathe für Nicht-Freaks"
    href: Literal["Mathe für Nicht-Freaks"] = "Mathe für Nicht-Freaks"
    books: List[Book] = field(default_factory=list)


@dataclass
class Book:
    name: str
    href: str
    kind: Literal["book"] = "book"
    sections: Literal[Section] = field(default_factory=list)


@dataclass
class Section:
    name: str
    kind: Literal["section"] = "section"
    pages: List[Page] = field(default_factory=list)


@dataclass
class Page:
    name: str
    href: str
    kind: Literal["page"] = "page"

def parse_sitemap(sitemap_text):
    project = Project()
    book = None
    section = None
    
    for line in sitemap_text.split("\n"):
        parsed_line = parse_sitemap_line(line)

        if parsed_line is None:
            continue

        if isinstance(parsed_line, BookLine):
            book = Book(name=parsed_line.name, href=parsed_line.href)
            section = None
            
            project.books.append(book)
        elif isinstance(parsed_line, SectionLine):
            section = Section(name=parsed_line.name)

            book.sections.append(section)
        elif isinstance(parsed_line, PageLine):
            page = Page(name=parsed_line.name, href=parsed_line.href)

            if section is None:
                for book_without_sections in ["Buchanfänge", "Über das Projekt"]:
                    if book.name == book_without_sections:
                        section = Section(name="Buchanfänge")
    
                        book.sections.append(section)

            section.pages.append(page)

    return project

project = parse_sitemap(raw_sitemap)

print(json.dumps(asdict(project), indent=2))
# Out:
# {
#   "kind": "project",
#   "name": "Mathe f\u00fcr Nicht-Freaks",
#   "href": "Mathe f\u00fcr Nicht-Freaks",
#   "books": [
#     {
#       "name": "Grundlagen der Mathematik",
#       "href": "Mathe f\u00fcr Nicht-Freaks: Grundlagen der Mathematik",
#       "kind": "book",
#       "sections": [
#         {
#           "name": "Was ist Mathematik?",
#           "kind": "section",
#           "pages": [
#             {
#               "name": "Was ist Mathematik?",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Was ist Mathematik?",
#               "kind": "page"
#             }
#           ]
#         },
#         {
#           "name": "Einf\u00fchrung in die Logik",
#           "kind": "section",
#           "pages": [
#             {
#               "name": "Logik und Aussagen",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Logik und Aussagen",
#               "kind": "page"
#             },
#             {
#               "name": "Junktoren",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Junktor",
#               "kind": "page"
#             },
#             {
#               "name": "Aussagenlogik",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Aussagenlogik",
#               "kind": "page"
#             },
#             {
#               "name": "Wahrheitstabelle",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Wahrheitstabelle",
#               "kind": "page"
#             },
#             {
#               "name": "Tautologien",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Tautologie",
#               "kind": "page"
#             },
#             {
#               "name": "Quantoren",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Quantor",
#               "kind": "page"
#             },
#             {
#               "name": "Aussageform und Substitution",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Aussageform und Substitution",
#               "kind": "page"
#             },
#             {
#               "name": "Pr\u00e4dikatenlogik",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Pr\u00e4dikatenlogik",
#               "kind": "page"
#             },
#             {
#               "name": "Aussagen formalisieren",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Aussagen formalisieren",
#               "kind": "page"
#             },
#             {
#               "name": "Aussagen negieren",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Aussagen negieren",
#               "kind": "page"
#             },
#             {
#               "name": "Klassenlogik",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Klassenlogik",
#               "kind": "page"
#             },
#             {
#               "name": "Gesetze der Logik",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Gesetze der Logik",
#               "kind": "page"
#             },
#             {
#               "name": "Aufgaben",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Aufgaben zur Logik",
#               "kind": "page"
#             }
#           ]
#         },
#         {
#           "name": "Beweise und Beweismethoden",
#           "kind": "section",
#           "pages": [
#             {
#               "name": "Was sind Beweise?",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Beweis",
#               "kind": "page"
#             },
#             {
#               "name": "Direkter und indirekter Beweis",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Direkter und indirekter Beweis",
#               "kind": "page"
#             },
#             {
#               "name": "Fallunterscheidung und Kontraposition",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Fallunterscheidung und Kontraposition",
#               "kind": "page"
#             },
#             {
#               "name": "Notwendige und hinreichende Bedingungen",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Notwendige und hinreichende Bedingungen",
#               "kind": "page"
#             }
#           ]
#         },
#         {
#           "name": "Vollst\u00e4ndige Induktion",
#           "kind": "section",
#           "pages": [
#             {
#               "name": "Definition und Erkl\u00e4rung",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Vollst\u00e4ndige Induktion",
#               "kind": "page"
#             },
#             {
#               "name": "Beispielaufgaben",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Vollst\u00e4ndige Induktion: Beispiele",
#               "kind": "page"
#             }
#           ]
#         },
#         {
#           "name": "Mengenlehre",
#           "kind": "section",
#           "pages": [
#             {
#               "name": "Definition einer Menge",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Mengenlehre: Menge",
#               "kind": "page"
#             },
#             {
#               "name": "Mengenschreibweisen",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Aufz\u00e4hlende und beschreibende Mengenschreibweise",
#               "kind": "page"
#             },
#             {
#               "name": "Euler- und Venn-Diagramme",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Mengendiagramme: Euler- und Venn-Diagramm",
#               "kind": "page"
#             },
#             {
#               "name": "Teilmenge und echte Teilmenge",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Teilmenge und echte Teilmenge",
#               "kind": "page"
#             },
#             {
#               "name": "Potenzmenge",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Potenzmenge",
#               "kind": "page"
#             },
#             {
#               "name": "Leere Menge und Allklasse",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Leere Menge und Allklasse",
#               "kind": "page"
#             },
#             {
#               "name": "Mengenverkn\u00fcpfungen",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Verkn\u00fcpfungen zwischen Mengen",
#               "kind": "page"
#             },
#             {
#               "name": "Durchschnitt von Mengen",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Durchschnitt von Mengen",
#               "kind": "page"
#             },
#             {
#               "name": "Vereinigung von Mengen",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Vereinigung von Mengen",
#               "kind": "page"
#             },
#             {
#               "name": "Grundlegende Operationen von Mengen",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Grundlegende Operationen von Mengen: Durchschnitt, Vereinigung und Komplement",
#               "kind": "page"
#             },
#             {
#               "name": "Differenz, symmetrische Differenz und Komplement",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Differenz, symmetrische Differenz und Komplement",
#               "kind": "page"
#             },
#             {
#               "name": "Boolesche Algebra",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Boolesche Algebra",
#               "kind": "page"
#             },
#             {
#               "name": "Disjunkte Mengen",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Disjunkte Mengen und paarweise disjunkte Mengensysteme",
#               "kind": "page"
#             },
#             {
#               "name": "Tupel und geordnetes Paar",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Tupel und geordnetes Paar",
#               "kind": "page"
#             },
#             {
#               "name": "Kartesisches Produkt",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Kartesisches Produkt",
#               "kind": "page"
#             },
#             {
#               "name": "Formeln der Mengenlehre",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Formeln der Mengenlehre",
#               "kind": "page"
#             },
#             {
#               "name": "Russells Antinomie und Klassen",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Russells Antinomie und Klassen",
#               "kind": "page"
#             },
#             {
#               "name": "Axiomatische Mengenlehre",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Axiomatische Mengenlehre",
#               "kind": "page"
#             }
#           ]
#         },
#         {
#           "name": "Relationen",
#           "kind": "section",
#           "pages": [
#             {
#               "name": "Relationen",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Relation",
#               "kind": "page"
#             },
#             {
#               "name": "Bin\u00e4re Relationen",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Bin\u00e4re Relation",
#               "kind": "page"
#             },
#             {
#               "name": "Eigenschaften bin\u00e4rer Relationen",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Eigenschaften bin\u00e4rer Relationen",
#               "kind": "page"
#             },
#             {
#               "name": "\u00c4quivalenzrelationen",
#               "href": "Mathe f\u00fcr Nicht-Freaks: \u00c4quivalenzrelation",
#               "kind": "page"
#             },
#             {
#               "name": "Ordnungsrelationen",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Ordnungsrelation",
#               "kind": "page"
#             }
#           ]
#         },
#         {
#           "name": "Abbildungen",
#           "kind": "section",
#           "pages": [
#             {
#               "name": "Abbildungen",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Abbildung, Funktion",
#               "kind": "page"
#             },
#             {
#               "name": "Verkn\u00fcpfungen",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Verkn\u00fcpfung",
#               "kind": "page"
#             }
#           ]
#         },
#         {
#           "name": "M\u00e4chtigkeit von Mengen",
#           "kind": "section",
#           "pages": [
#             {
#               "name": "M\u00e4chtigkeit von Mengen",
#               "href": "Mathe f\u00fcr Nicht-Freaks: M\u00e4chtigkeit von Mengen",
#               "kind": "page"
#             }
#           ]
#         },
#         {
#           "name": "Gleichungsumformungen",
#           "kind": "section",
#           "pages": [
#             {
#               "name": "Gleichungsumformungen",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Gleichungen: Umformungen",
#               "kind": "page"
#             },
#             {
#               "name": "Termumformungen",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Terme: Umformungen",
#               "kind": "page"
#             },
#             {
#               "name": "Aufgaben",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Aufgaben zu Gleichungsumformungen",
#               "kind": "page"
#             }
#           ]
#         },
#         {
#           "name": "Summe, Produkt und Fakult\u00e4t",
#           "kind": "section",
#           "pages": [
#             {
#               "name": "Summe und Produkt",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Summe und Produkt",
#               "kind": "page"
#             },
#             {
#               "name": "Gau\u00dfsche Summenformel",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Gau\u00dfsche Summenformel",
#               "kind": "page"
#             },
#             {
#               "name": "Geometrische Summenformel",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Geometrische Summenformel",
#               "kind": "page"
#             },
#             {
#               "name": "Eigenschaften f\u00fcr Summe und Produkt",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Eigenschaften f\u00fcr Summe und Produkt",
#               "kind": "page"
#             },
#             {
#               "name": "Fakult\u00e4t",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Fakult\u00e4t",
#               "kind": "page"
#             }
#           ]
#         },
#         {
#           "name": "Binomialkoeffizient",
#           "kind": "section",
#           "pages": [
#             {
#               "name": "Binomialkoeffizient",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Binomialkoeffizient",
#               "kind": "page"
#             },
#             {
#               "name": "Der binomische Lehrsatz",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Binomischer Lehrsatz",
#               "kind": "page"
#             },
#             {
#               "name": "Rechenregeln",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Binomialkoeffizient: Rechenregeln",
#               "kind": "page"
#             }
#           ]
#         },
#         {
#           "name": "Anhang",
#           "kind": "section",
#           "pages": [
#             {
#               "name": "W\u00f6rterbuch mathematischer Begriffe",
#               "href": "Mathe f\u00fcr Nicht-Freaks: W\u00f6rterbuch",
#               "kind": "page"
#             },
#             {
#               "name": "Liste mathematischer Symbole",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Liste mathematischer Symbole",
#               "kind": "page"
#             },
#             {
#               "name": "Zusammenfassung",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Grundlagen der Mathematik: Zusammenfassung",
#               "kind": "page"
#             },
#             {
#               "name": "PDF-Version (Beta)",
#               "href": "c:File:Grundlagen der Mathematik.pdf",
#               "kind": "page"
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "name": "Analysis 1",
#       "href": "Mathe f\u00fcr Nicht-Freaks: Analysis 1",
#       "kind": "book",
#       "sections": [
#         {
#           "name": "Was ist Analysis?",
#           "kind": "section",
#           "pages": [
#             {
#               "name": "Was ist Analysis?",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Was ist Analysis?",
#               "kind": "page"
#             },
#             {
#               "name": "Wozu Analysis studieren?",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Wozu Analysis studieren?",
#               "kind": "page"
#             }
#           ]
#         },
#         {
#           "name": "Was sind reelle Zahlen?",
#           "kind": "section",
#           "pages": [
#             {
#               "name": "Was sind reelle Zahlen?",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Reelle Zahlen",
#               "kind": "page"
#             },
#             {
#               "name": "Die Zahlengerade",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Zahlengerade",
#               "kind": "page"
#             }
#           ]
#         },
#         {
#           "name": "K\u00f6rperaxiome",
#           "kind": "section",
#           "pages": [
#             {
#               "name": "K\u00f6rperaxiome",
#               "href": "Mathe f\u00fcr Nicht-Freaks: K\u00f6rperaxiome",
#               "kind": "page"
#             },
#             {
#               "name": "Folgerungen aus den K\u00f6rperaxiomen",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Folgerungen aus den K\u00f6rperaxiomen",
#               "kind": "page"
#             },
#             {
#               "name": "Potenzen reeller Zahlen",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Potenz",
#               "kind": "page"
#             }
#           ]
#         },
#         {
#           "name": "Anordnungsaxiome",
#           "kind": "section",
#           "pages": [
#             {
#               "name": "Anordnungsaxiome",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Anordnungsaxiome",
#               "kind": "page"
#             },
#             {
#               "name": "Folgerungen der Anordnungsaxiome",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Folgerungen der Anordnungsaxiome",
#               "kind": "page"
#             },
#             {
#               "name": "Betragsfunktion, Maximum und Minimum",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Betrag, Maximum und Minimum",
#               "kind": "page"
#             },
#             {
#               "name": "Intervalle",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Intervall",
#               "kind": "page"
#             }
#           ]
#         },
#         {
#           "name": "Vollst\u00e4ndigkeit reeller Zahlen",
#           "kind": "section",
#           "pages": [
#             {
#               "name": "Intervallschachtelung mit rationaler Genauigkeit",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Intervallschachtelung mit rationaler Genauigkeit",
#               "kind": "page"
#             },
#             {
#               "name": "Das archimedische Axiom",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Archimedisches Axiom",
#               "kind": "page"
#             },
#             {
#               "name": "Bernoullische Ungleichung",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Bernoulli-Ungleichung",
#               "kind": "page"
#             },
#             {
#               "name": "Allgemeine Intervallschachtelungen",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Allgemeine Intervallschachtelung",
#               "kind": "page"
#             }
#           ]
#         },
#         {
#           "name": "Die komplexen Zahlen",
#           "kind": "section",
#           "pages": [
#             {
#               "name": "Einleitung und Motivation",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Komplexe Zahlen: Einleitung und Motivation",
#               "kind": "page"
#             },
#             {
#               "name": "Definition komplexer Zahlen",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Komplexen Zahlen: Definition",
#               "kind": "page"
#             },
#             {
#               "name": "Betrag und Konjugation",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Komplexe Konjugation und Betrag komplexer Zahlen",
#               "kind": "page"
#             },
#             {
#               "name": "Polardarstellung",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Polarform bzw. Polardarstellung komplexer Zahlen",
#               "kind": "page"
#             },
#             {
#               "name": "Darstellung komplexwertiger Funktionen",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Komplexe Zahlen: Darstellung komplexwertiger Funktionen",
#               "kind": "page"
#             },
#             {
#               "name": "Aufgaben",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Aufgaben zu komplexen Zahlen",
#               "kind": "page"
#             }
#           ]
#         },
#         {
#           "name": "Supremum und Infimum",
#           "kind": "section",
#           "pages": [
#             {
#               "name": "Supremum und Infimum",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Supremum und Infimum",
#               "kind": "page"
#             },
#             {
#               "name": "Uneigentliches Supremum und Infimum",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Uneigentliches Supremum und Infimum",
#               "kind": "page"
#             },
#             {
#               "name": "Supremum und Infimum bestimmen und beweisen",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Supremum und Infimum bestimmen und beweisen",
#               "kind": "page"
#             },
#             {
#               "name": "Eigenschaften Supremum und Infimum",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Supremum und Infimum: Eigenschaften",
#               "kind": "page"
#             }
#           ]
#         },
#         {
#           "name": "Wurzel reeller Zahlen",
#           "kind": "section",
#           "pages": [
#             {
#               "name": "Wurzel reeller Zahlen",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Wurzel",
#               "kind": "page"
#             },
#             {
#               "name": "L\u00f6sungen von Potenzgleichungen",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Potenzgleichungen",
#               "kind": "page"
#             },
#             {
#               "name": "Rechenregeln",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Rechenregeln der Wurzel",
#               "kind": "page"
#             },
#             {
#               "name": "Verallgemeinerte Potenzen",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Potenzen mit rationalem Exponenten",
#               "kind": "page"
#             },
#             {
#               "name": "Aufgaben",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Aufgaben zu Wurzeln",
#               "kind": "page"
#             }
#           ]
#         },
#         {
#           "name": "Folgen",
#           "kind": "section",
#           "pages": [
#             {
#               "name": "Definition",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Folge",
#               "kind": "page"
#             },
#             {
#               "name": "Explizite und rekursive Bildungsgesetze",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Explizite und rekursive Bildungsgesetze f\u00fcr Folgen",
#               "kind": "page"
#             },
#             {
#               "name": "Beispiele und Eigenschaften",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Beispiele und Eigenschaften von Folgen",
#               "kind": "page"
#             },
#             {
#               "name": "Aufgaben",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Aufgaben zu Folgen",
#               "kind": "page"
#             }
#           ]
#         },
#         {
#           "name": "Konvergenz und Divergenz",
#           "kind": "section",
#           "pages": [
#             {
#               "name": "Definition Grenzwert",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Grenzwert: Konvergenz und Divergenz",
#               "kind": "page"
#             },
#             {
#               "name": "Konvergenz und Divergenz beweisen",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Konvergenz und Divergenz beweisen",
#               "kind": "page"
#             },
#             {
#               "name": "Beispiele f\u00fcr Grenzwerte",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Grenzwert: Beispiele",
#               "kind": "page"
#             },
#             {
#               "name": "Unbeschr\u00e4nkte Folgen divergieren",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Unbeschr\u00e4nkte Folgen divergieren",
#               "kind": "page"
#             },
#             {
#               "name": "Grenzwerts\u00e4tze",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Grenzwerts\u00e4tze: Grenzwert von Folgen berechnen",
#               "kind": "page"
#             },
#             {
#               "name": "Der Sandwichsatz",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Sandwichsatz, Einschn\u00fcrungssatz, Einschlie\u00dfungssatz",
#               "kind": "page"
#             },
#             {
#               "name": "Monotoniekriterium",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Monotoniekriterium f\u00fcr Folgen",
#               "kind": "page"
#             },
#             {
#               "name": "Konvergenzbeweise rekursiver Folgen",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Konvergenz rekursiver Folgen beweisen",
#               "kind": "page"
#             },
#             {
#               "name": "Aufgaben",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Aufgaben zur Konvergenz und Divergenz",
#               "kind": "page"
#             }
#           ]
#         },
#         {
#           "name": "Teilfolgen, H\u00e4ufungspunkte und Cauchy-Folgen",
#           "kind": "section",
#           "pages": [
#             {
#               "name": "Teilfolgen",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Teilfolge",
#               "kind": "page"
#             },
#             {
#               "name": "H\u00e4ufungspunkte von Folgen",
#               "href": "Mathe f\u00fcr Nicht-Freaks: H\u00e4ufungspunkt einer Folge",
#               "kind": "page"
#             },
#             {
#               "name": "H\u00e4ufungs- und Ber\u00fchrpunkte von Mengen",
#               "href": "Mathe f\u00fcr Nicht-Freaks: H\u00e4ufungspunkt und Ber\u00fchrpunkt einer Menge",
#               "kind": "page"
#             },
#             {
#               "name": "Satz von Bolzano-Weierstra\u00df",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Satz von Bolzano-Weierstra\u00df",
#               "kind": "page"
#             },
#             {
#               "name": "Bestimmte Divergenz",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Bestimmte Divergenz, uneigentliche Konvergenz",
#               "kind": "page"
#             },
#             {
#               "name": "Bestimmte Divergenz: Regeln",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Rechenregeln der bestimmten Divergenz",
#               "kind": "page"
#             },
#             {
#               "name": "Lim sup und Lim inf",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Lim sup und Lim inf",
#               "kind": "page"
#             },
#             {
#               "name": "Cauchy-Folgen",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Cauchy-Folgen und das Cauchy-Kriterium",
#               "kind": "page"
#             },
#             {
#               "name": "Aufgaben",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Aufgaben zu Teilfolgen, H\u00e4ufungspunkte und Cauchy-Folgen",
#               "kind": "page"
#             }
#           ]
#         },
#         {
#           "name": "Reihen",
#           "kind": "section",
#           "pages": [
#             {
#               "name": "Begriff der Reihe",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Reihe",
#               "kind": "page"
#             },
#             {
#               "name": "Rechenregeln f\u00fcr Reihen",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Rechenregeln f\u00fcr Reihen",
#               "kind": "page"
#             },
#             {
#               "name": "Teleskopsumme und Teleskopreihe",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Teleskopsumme und Teleskopreihe",
#               "kind": "page"
#             },
#             {
#               "name": "Geometrische Reihe",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Geometrische Reihe",
#               "kind": "page"
#             },
#             {
#               "name": "Harmonische Reihe",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Harmonische Reihe",
#               "kind": "page"
#             },
#             {
#               "name": "e-Reihe",
#               "href": "Mathe f\u00fcr Nicht-Freaks: e-Reihe",
#               "kind": "page"
#             },
#             {
#               "name": "Absolute Konvergenz einer Reihe",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Absolute Konvergenz einer Reihe",
#               "kind": "page"
#             },
#             {
#               "name": "Umordnungssatz f\u00fcr Reihen",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Umordnungssatz f\u00fcr Reihen",
#               "kind": "page"
#             },
#             {
#               "name": "Cauchy-Produkt f\u00fcr Reihen",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Cauchy-Produkt f\u00fcr Reihen",
#               "kind": "page"
#             },
#             {
#               "name": "Aufgaben",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Aufgaben zu Reihen",
#               "kind": "page"
#             }
#           ]
#         },
#         {
#           "name": "Konvergenzkriterien f\u00fcr Reihen",
#           "kind": "section",
#           "pages": [
#             {
#               "name": "\u00dcbersicht Konvergenzkriterien",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Konvergenz und Divergenz einer Reihe beweisen: Konvergenzkriterien",
#               "kind": "page"
#             },
#             {
#               "name": "Cauchy-Kriterium",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Cauchy-Kriterium f\u00fcr Reihen",
#               "kind": "page"
#             },
#             {
#               "name": "Trivialkriterium",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Trivialkriterium, Nullfolgenkriterium, Divergenzkriterium",
#               "kind": "page"
#             },
#             {
#               "name": "Beschr\u00e4nkte Reihen und Konvergenz",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Beschr\u00e4nkte Reihen und Konvergenz",
#               "kind": "page"
#             },
#             {
#               "name": "Majoranten- und Minorantenkriterium",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Majorantenkriterium und Minorantenkriterium",
#               "kind": "page"
#             },
#             {
#               "name": "Wurzelkriterium",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Wurzelkriterium",
#               "kind": "page"
#             },
#             {
#               "name": "Quotientenkriterium",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Quotientenkriterium",
#               "kind": "page"
#             },
#             {
#               "name": "Leibniz-Kriterium",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Leibniz-Kriterium",
#               "kind": "page"
#             },
#             {
#               "name": "Verdichtungskriterium",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Cauchysches Verdichtungskriterium",
#               "kind": "page"
#             },
#             {
#               "name": "Anwendung der Konvergenzkriterien",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Anwendung der Konvergenzkriterien bei Reihen",
#               "kind": "page"
#             },
#             {
#               "name": "Aufgaben",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Aufgaben zu Konvergenzkriterien f\u00fcr Reihen",
#               "kind": "page"
#             }
#           ]
#         },
#         {
#           "name": "Potenzreihen",
#           "kind": "section",
#           "pages": [
#             {
#               "name": "Definition und Beispiele",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Potenzreihen",
#               "kind": "page"
#             },
#             {
#               "name": "Konvergenzradius",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Konvergenzradius von Potenzreihen",
#               "kind": "page"
#             },
#             {
#               "name": "Aufgaben",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Aufgaben zu Potenzreihen",
#               "kind": "page"
#             }
#           ]
#         },
#         {
#           "name": "Exponential- und Logarithmusfunktion",
#           "kind": "section",
#           "pages": [
#             {
#               "name": "Herleitung und Definition der Exponentialfunktion",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Herleitung und Definition der Exponentialfunktion",
#               "kind": "page"
#             },
#             {
#               "name": "Eigenschaften der Exponentialfunktion",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Eigenschaften der Exponentialfunktion",
#               "kind": "page"
#             },
#             {
#               "name": "Logarithmusfunktion",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Die Logarithmusfunktion",
#               "kind": "page"
#             },
#             {
#               "name": "Verallgemeinerte Potenzen",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Potenzen mit reellen Exponenten",
#               "kind": "page"
#             },
#             {
#               "name": "Exponential- und Logarithmusfunktion in den komplexen Zahlen",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Exponential- und Logarithmusfunktion in den komplexen Zahlen",
#               "kind": "page"
#             },
#             {
#               "name": "Aufgaben",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Aufgaben zur Exponential- und Logarithmusfunktion",
#               "kind": "page"
#             }
#           ]
#         },
#         {
#           "name": "Trigonometrische und Hyperbolische Funktionen",
#           "kind": "section",
#           "pages": [
#             {
#               "name": "Sinus und Kosinus",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Sinus und Kosinus",
#               "kind": "page"
#             },
#             {
#               "name": "Eigenschaften des Sinus und Kosinus",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Eigenschaften des Sinus und Kosinus",
#               "kind": "page"
#             },
#             {
#               "name": "Arkussinus und Arkuskosinus",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Arkussinus und Arkuskosinus",
#               "kind": "page"
#             },
#             {
#               "name": "Tangens und Kotangens",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Tangens und Kotangens",
#               "kind": "page"
#             },
#             {
#               "name": "Arkustangens und Arkuskotangens",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Arkustangens und Arkuskotangens",
#               "kind": "page"
#             },
#             {
#               "name": "Sinus Hyperbolicus und Kosinus Hyperbolicus",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Sinus Hyperbolicus und Kosinus Hyperbolicus",
#               "kind": "page"
#             },
#             {
#               "name": "Aufgaben",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Aufgaben zu trigonometrischen und hyperbolischen Funktionen",
#               "kind": "page"
#             }
#           ]
#         },
#         {
#           "name": "Stetigkeit",
#           "kind": "section",
#           "pages": [
#             {
#               "name": "Stetigkeit von Funktionen",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Stetigkeit von Funktionen",
#               "kind": "page"
#             },
#             {
#               "name": "Folgenkriterium",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Folgenkriterium der Stetigkeit: Folgenstetigkeit",
#               "kind": "page"
#             },
#             {
#               "name": "Epsilon-Delta-Kriterium",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Epsilon-Delta-Kriterium der Stetigkeit",
#               "kind": "page"
#             },
#             {
#               "name": "Grenzwert von Funktionen",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Grenzwert von Funktionen",
#               "kind": "page"
#             },
#             {
#               "name": "Komposition stetiger Funktionen",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Komposition stetiger Funktionen",
#               "kind": "page"
#             },
#             {
#               "name": "Stetigkeit beweisen",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Stetigkeit beweisen: Epsilon-Delta-Kriterium und Folgenkriterium",
#               "kind": "page"
#             },
#             {
#               "name": "Unstetigkeit beweisen",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Unstetigkeit beweisen: Epsilon-Delta-Kriterium und Folgenkriterium",
#               "kind": "page"
#             },
#             {
#               "name": "Zwischenwertsatz",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Zwischenwertsatz",
#               "kind": "page"
#             },
#             {
#               "name": "Satz vom Minimum und Maximum",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Satz vom Minimum und Maximum",
#               "kind": "page"
#             },
#             {
#               "name": "Stetigkeit der Umkehrfunktion",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Stetigkeit der Umkehrfunktion",
#               "kind": "page"
#             },
#             {
#               "name": "Gleichm\u00e4\u00dfige Stetigkeit",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Gleichm\u00e4\u00dfige Stetigkeit",
#               "kind": "page"
#             },
#             {
#               "name": "Lipschitz-Stetigkeit",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Lipschitz-Stetigkeit",
#               "kind": "page"
#             },
#             {
#               "name": "Aufgaben",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Aufgaben zur Stetigkeit",
#               "kind": "page"
#             }
#           ]
#         },
#         {
#           "name": "Ableitung",
#           "kind": "section",
#           "pages": [
#             {
#               "name": "Ableitung",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Ableitung und Differenzierbarkeit",
#               "kind": "page"
#             },
#             {
#               "name": "Ableitungsregeln",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Ableitungsregeln: Kettenregel, Quotientenregel, Produktregel, Summenregel, Faktorregel",
#               "kind": "page"
#             },
#             {
#               "name": "Spezielle Ableitungsregeln",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Spezielle Ableitungsregeln",
#               "kind": "page"
#             },
#             {
#               "name": "Ableitung der Umkehrfunktion",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Ableitung der Umkehrfunktion",
#               "kind": "page"
#             },
#             {
#               "name": "Beispiele f\u00fcr Ableitungen",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Beispiele f\u00fcr Ableitungen",
#               "kind": "page"
#             },
#             {
#               "name": "Ableitung h\u00f6herer Ordnung",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Ableitung h\u00f6herer Ordnung",
#               "kind": "page"
#             },
#             {
#               "name": "Satz von Rolle",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Satz von Rolle",
#               "kind": "page"
#             },
#             {
#               "name": "Mittelwertsatz",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Mittelwertsatz",
#               "kind": "page"
#             },
#             {
#               "name": "Konstanzkriterium",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Konstanzkriterium: Zusammenhang zwischen Konstanz einer Funktion und ihrer Ableitung",
#               "kind": "page"
#             },
#             {
#               "name": "Monotoniekriterium",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Monotoniekriterium: Zusammenhang zwischen Monotonie und Ableitung einer Funktion",
#               "kind": "page"
#             },
#             {
#               "name": "Ableitung und lokale Extrema",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Ableitung und lokale Extrema",
#               "kind": "page"
#             },
#             {
#               "name": "Regel von L'Hospital",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Regel von L'Hospital",
#               "kind": "page"
#             },
#             {
#               "name": "\u00dcbersicht: Stetigkeit und Differenzierbarkeit",
#               "href": "Mathe f\u00fcr Nicht-Freaks: \u00dcbersicht: Stetigkeit und Differenzierbarkeit",
#               "kind": "page"
#             },
#             {
#               "name": "Aufgaben 1",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Aufgaben zur Ableitung 1",
#               "kind": "page"
#             },
#             {
#               "name": "Aufgaben 2",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Aufgaben zur Ableitung 2",
#               "kind": "page"
#             },
#             {
#               "name": "Aufgaben 3",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Aufgaben zur Ableitung 3",
#               "kind": "page"
#             },
#             {
#               "name": "Aufgaben 4",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Aufgaben zur Ableitung 4",
#               "kind": "page"
#             }
#           ]
#         },
#         {
#           "name": "Integrale",
#           "kind": "section",
#           "pages": [
#             {
#               "name": "Das Integral",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Integral einer Funktion",
#               "kind": "page"
#             },
#             {
#               "name": "Riemannintegral",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Riemannintegral",
#               "kind": "page"
#             },
#             {
#               "name": "Eigenschaften des Riemannintegrals",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Eigenschaften des Riemannintegrals",
#               "kind": "page"
#             },
#             {
#               "name": "Regelintegral",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Regelintegral",
#               "kind": "page"
#             },
#             {
#               "name": "Mittelwertsatz f\u00fcr Integrale",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Mittelwertsatz f\u00fcr Integrale",
#               "kind": "page"
#             },
#             {
#               "name": "Hauptsatz der Differential- und Integralrechnung",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Hauptsatz der Differential- und Integralrechnung",
#               "kind": "page"
#             },
#             {
#               "name": "Substitutionsregel",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Substitutionsregel f\u00fcr Integrale",
#               "kind": "page"
#             },
#             {
#               "name": "Partielle Integration",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Partielle Integration",
#               "kind": "page"
#             },
#             {
#               "name": "Uneigentliche Integrale",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Uneigentliche Integrale",
#               "kind": "page"
#             },
#             {
#               "name": "Beispiele f\u00fcr Integrale",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Beispiele f\u00fcr Integrale",
#               "kind": "page"
#             },
#             {
#               "name": "Aufgaben",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Aufgaben zu Integralen",
#               "kind": "page"
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "name": "Lineare Algebra 1",
#       "href": "Mathe f\u00fcr Nicht-Freaks: Lineare Algebra 1",
#       "kind": "book",
#       "sections": [
#         {
#           "name": "Einf\u00fchrung in die lineare Algebra",
#           "kind": "section",
#           "pages": [
#             {
#               "name": "Was ist Algebra?",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Was ist Algebra?",
#               "kind": "page"
#             },
#             {
#               "name": "Gruppen",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Gruppen",
#               "kind": "page"
#             },
#             {
#               "name": "Ringe",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Ringe",
#               "kind": "page"
#             },
#             {
#               "name": "K\u00f6rper",
#               "href": "Mathe f\u00fcr Nicht-Freaks: K\u00f6rper",
#               "kind": "page"
#             },
#             {
#               "name": "Vektorbegriff aus der Schule",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Vektoren und Vektorr\u00e4ume in der Schule",
#               "kind": "page"
#             }
#           ]
#         },
#         {
#           "name": "Vektorr\u00e4ume",
#           "kind": "section",
#           "pages": [
#             {
#               "name": "Einf\u00fchrung in den Vektorraum",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Einf\u00fchrung in den Vektorraum",
#               "kind": "page"
#             },
#             {
#               "name": "Vektorraum",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Vektorraum",
#               "kind": "page"
#             },
#             {
#               "name": "Eigenschaften von Vektorr\u00e4umen",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Vektorraum: Eigenschaften",
#               "kind": "page"
#             },
#             {
#               "name": "Beweise f\u00fcr Vektorr\u00e4ume f\u00fchren",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Beweise f\u00fcr Vektorr\u00e4ume f\u00fchren",
#               "kind": "page"
#             },
#             {
#               "name": "Der K\u00f6rper als Vektorraum",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Der K\u00f6rper als Vektorraum",
#               "kind": "page"
#             },
#             {
#               "name": "Koordinatenr\u00e4ume",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Koordinatenr\u00e4ume",
#               "kind": "page"
#             },
#             {
#               "name": "Folgenr\u00e4ume",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Folgenr\u00e4ume",
#               "kind": "page"
#             },
#             {
#               "name": "Funktionenraum",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Funktionenraum",
#               "kind": "page"
#             },
#             {
#               "name": "Untervektorraum",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Untervektorraum",
#               "kind": "page"
#             },
#             {
#               "name": "Vereinigung und Durchschnitt von Vektorr\u00e4umen",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Vereinigung und Durchschnitt von Vektorr\u00e4umen",
#               "kind": "page"
#             },
#             {
#               "name": "Summe von Unterr\u00e4umen",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Vektorraum: Summe von Unterr\u00e4umen",
#               "kind": "page"
#             },
#             {
#               "name": "Innere direkte Summe",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Vektorraum: Innere direkte Summe",
#               "kind": "page"
#             },
#             {
#               "name": "Komplement",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Vektorraum: Komplement",
#               "kind": "page"
#             },
#             {
#               "name": "Nebenklassen eines Unterraums",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Nebenklassen eines Unterraums",
#               "kind": "page"
#             },
#             {
#               "name": "Faktorraum",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Faktorraum, Quotientenraum",
#               "kind": "page"
#             }
#           ]
#         },
#         {
#           "name": "Linearkombinationen, Erzeugendensystem und Basis",
#           "kind": "section",
#           "pages": [
#             {
#               "name": "Linearkombinationen",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Linearkombinationen",
#               "kind": "page"
#             },
#             {
#               "name": "Spann einer Menge",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Spann, Erzeugnis, lineare H\u00fclle",
#               "kind": "page"
#             },
#             {
#               "name": "Erzeugendensystem",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Erzeugendensystem",
#               "kind": "page"
#             },
#             {
#               "name": "Lineare Unabh\u00e4ngigkeit von Vektoren",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Lineare Unabh\u00e4ngigkeit von Vektoren",
#               "kind": "page"
#             },
#             {
#               "name": "Basis eines Vektorraums",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Basis eines Vektorraums",
#               "kind": "page"
#             },
#             {
#               "name": "Austauschlemma und Austauschsatz von Steinitz",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Austauschlemma und Austauschsatz von Steinitz",
#               "kind": "page"
#             },
#             {
#               "name": "Dimension eines Vektorraums",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Dimension eines Vektorraums",
#               "kind": "page"
#             }
#           ]
#         },
#         {
#           "name": "Lineare Abbildungen",
#           "kind": "section",
#           "pages": [
#             {
#               "name": "Lineare Abbildungen",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Lineare Abbildungen, Homomorphismus",
#               "kind": "page"
#             },
#             {
#               "name": "Eigenschaften linearer Abbildungen",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Eigenschaften Linearer Abbildungen",
#               "kind": "page"
#             },
#             {
#               "name": "Prinzip der linearen Fortsetzung",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Prinzip der linearen Fortsetzung",
#               "kind": "page"
#             },
#             {
#               "name": "Beweise f\u00fcr lineare Abbildungen f\u00fchren",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Beweise f\u00fcr lineare Abbildungen f\u00fchren",
#               "kind": "page"
#             },
#             {
#               "name": "Monomorphismus",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Monomorphismus (Lineare Algebra)",
#               "kind": "page"
#             },
#             {
#               "name": "Epimorphismus",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Epimorphismus (Lineare Algebra)",
#               "kind": "page"
#             },
#             {
#               "name": "Isomorphismus",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Isomorphismus (Lineare Algebra)",
#               "kind": "page"
#             },
#             {
# ...
#             }
#           ]
#         },
#         {
#           "name": "Matrices",
#           "kind": "section",
#           "pages": [
#             {
#               "name": "Introduction: Matrices",
#               "href": "Serlo: EN: Introduction: Matrices",
#               "kind": "page"
#             },
#             {
#               "name": "Matrix of a linear map",
#               "href": "Serlo: EN: Matrix of a linear map",
#               "kind": "page"
#             },
#             {
#               "name": "Definition of a matrix",
#               "href": "Serlo: EN: Definition of a matrix",
#               "kind": "page"
#             },
#             {
#               "name": "Linear systems and matrices",
#               "href": "Serlo: EN: Linear systems and matrices",
#               "kind": "page"
#             },
#             {
#               "name": "Vector space structure on matrices",
#               "href": "Serlo: EN: Vector space structure on matrices",
#               "kind": "page"
#             },
#             {
#               "name": "Matrix multiplication",
#               "href": "Serlo: EN: Matrix multiplication",
#               "kind": "page"
#             },
#             {
#               "name": "Basis change via matrices",
#               "href": "Serlo: EN: Basis change via matrices",
#               "kind": "page"
#             },
#             {
#               "name": "Exercises",
#               "href": "Serlo: EN: Exercises: Matrices",
#               "kind": "page"
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "name": "Measure theory",
#       "href": "Serlo: EN: Measure theory",
#       "kind": "book",
#       "sections": [
#         {
#           "name": "Introduction, basic definitions",
#           "kind": "section",
#           "pages": [
#             {
#               "name": "Overview: Objects in Measure Theory",
#               "href": "Serlo: EN: Overview: Objects in Measure Theory",
#               "kind": "page"
#             },
#             {
#               "name": "Volumes on rings",
#               "href": "Serlo: EN: Volumes on rings",
#               "kind": "page"
#             },
#             {
#               "name": "Continuity of volumes on rings",
#               "href": "Serlo: EN: Continuity of volumes on rings",
#               "kind": "page"
#             },
#             {
#               "name": "Pre-measures and measures",
#               "href": "Serlo: EN: Pre-measures and measures",
#               "kind": "page"
#             }
#           ]
#         },
#         {
#           "name": "Constructing measures",
#           "kind": "section",
#           "pages": [
#             {
#               "name": "Constructing measures: overview",
#               "href": "Serlo: EN: Constructing measures: overview",
#               "kind": "page"
#             },
#             {
#               "name": "Generated sigma-algebras",
#               "href": "Serlo: EN: Generated sigma-algebras",
#               "kind": "page"
#             },
#             {
#               "name": "Existence of a measure continuation",
#               "href": "Serlo: EN: Existence of a measure continuation",
#               "kind": "page"
#             },
#             {
#               "name": "Uniqueness of a continuation",
#               "href": "Serlo: EN: Uniqueness of a continuation",
#               "kind": "page"
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "name": "Buchanf\u00e4nge",
#       "href": "Mathe f\u00fcr Nicht-Freaks: Buchanf\u00e4nge",
#       "kind": "book",
#       "sections": [
#         {
#           "name": "Buchanf\u00e4nge",
#           "kind": "section",
#           "pages": [
#             {
#               "name": "Algebra",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Buchanfang Algebra by Morrison69",
#               "kind": "page"
#             },
#             {
#               "name": "Gew\u00f6hnliche Differentialgleichungen",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Buchanfang Gew\u00f6hnliche Differentialgleichungen by Stephan Kulla",
#               "kind": "page"
#             },
#             {
#               "name": "Ma\u00dftheorie",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Buchanfang Ma\u00dftheorie by Richard4321",
#               "kind": "page"
#             },
#             {
#               "name": "Partielle Differentialgleichungen",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Buchanfang Partielle Differentialgleichungen by Richard4321",
#               "kind": "page"
#             },
#             {
#               "name": "Analysis 2",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Analysis 2",
#               "kind": "page"
#             },
#             {
#               "name": "Lineare Algebra",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Buchanfang lineare Algebra",
#               "kind": "page"
#             },
#             {
#               "name": "Lineare Algebra 2",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Buchanfang lineare Algebra 2",
#               "kind": "page"
#             },
#             {
#               "name": "Abstellraum",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Abstellraum",
#               "kind": "page"
#             },
#             {
#               "name": "Taylor Entwicklung",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Taylor Entwicklung",
#               "kind": "page"
#             },
#             {
#               "name": "Wahrscheinlichkeitstheorie",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Wahrscheinlichkeitstheorie",
#               "kind": "page"
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "name": "Mitmachen f\u00fcr (Nicht-)Freaks",
#       "href": "Mathe f\u00fcr Nicht-Freaks: Mitmachen f\u00fcr (Nicht-)Freaks",
#       "kind": "book",
#       "sections": [
#         {
#           "name": "Erste Schritte",
#           "kind": "section",
#           "pages": [
#             {
#               "name": "Wer kann mitmachen?",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Wer kann mitmachen",
#               "kind": "page"
#             },
#             {
#               "name": "Wie kann ich beitragen?",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Wie kann ich beitragen",
#               "kind": "page"
#             },
#             {
#               "name": "Wie melde ich mich an?",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Wie melde ich mich an",
#               "kind": "page"
#             },
#             {
#               "name": "Wer sind meine Ansprechpersonen?",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Wer sind meine Ansprechpersonen",
#               "kind": "page"
#             },
#             {
#               "name": "Wie fange ich ein neues Buch an?",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Wie fange ich ein neues Buch an",
#               "kind": "page"
#             },
#             {
#               "name": "Eine pers\u00f6nliche Spielwiese erstellen",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Eine pers\u00f6nliche Spielwiese erstellen",
#               "kind": "page"
#             },
#             {
#               "name": "Einen Artikel bearbeiten",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Einen Artikel bearbeiten",
#               "kind": "page"
#             },
#             {
#               "name": "Beispielartikel",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Beispielartikel",
#               "kind": "page"
#             },
#             {
#               "name": "Hilfreiche Links",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Hilfreiche Links",
#               "kind": "page"
#             }
#           ]
#         },
#         {
#           "name": "Zusammenarbeit",
#           "kind": "section",
#           "pages": [
#             {
#               "name": "Interaktion mit der Community",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Interaktion mit der Community",
#               "kind": "page"
#             },
#             {
#               "name": "Best Practices f\u00fcr Entscheidungsprozesse",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Best Practices f\u00fcr Entscheidungsprozesse",
#               "kind": "page"
#             },
#             {
#               "name": "Umfragen",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Umfragen",
#               "kind": "page"
#             },
#             {
#               "name": "Wie gebe ich gutes Feedback?",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Wie gebe ich gutes Feedback",
#               "kind": "page"
#             }
#           ]
#         },
#         {
#           "name": "Unser Arbeitsprozess",
#           "kind": "section",
#           "pages": [
#             {
#               "name": "Artikelworkflow",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Artikelworkflow",
#               "kind": "page"
#             },
#             {
#               "name": "Phabricator",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Phabricator",
#               "kind": "page"
#             },
#             {
#               "name": "Grundvorstellung finden",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Grundvorstellung finden",
#               "kind": "page"
#             },
#             {
#               "name": "Artikelplan erstellen",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Artikelplan erstellen",
#               "kind": "page"
#             },
#             {
#               "name": "Bestehende Artikel \u00fcberarbeiten",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Bestehende Artikel \u00fcberarbeiten",
#               "kind": "page"
#             }
#           ]
#         },
#         {
#           "name": "Bearbeiten von Inhalten",
#           "kind": "section",
#           "pages": [
#             {
#               "name": "Wie funktioniert der Editor?",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Wie funktioniert der Editor",
#               "kind": "page"
#             },
#             {
#               "name": "Grundlegende Formatierungen",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Grundlegende Formatierungen",
#               "kind": "page"
#             },
#             {
#               "name": "Vorlagen",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Vorlagen",
#               "kind": "page"
#             },
#             {
#               "name": "Formelumgebung",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Formelumgebung",
#               "kind": "page"
#             },
#             {
#               "name": "Spickzettel f\u00fcr Mathe-Formeln",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Spickzettel f\u00fcr Mathe-Formeln",
#               "kind": "page"
#             },
#             {
#               "name": "Hochladen und Einbinden von Medien",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Hochladen und Einbinden von Medien",
#               "kind": "page"
#             },
#             {
#               "name": "Inhalte doppelt Einbinden",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Inhalte doppelt einbinden",
#               "kind": "page"
#             }
#           ]
#         },
#         {
#           "name": "Konventionen",
#           "kind": "section",
#           "pages": [
#             {
#               "name": "Sprachliche Konventionen",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Sprachliche Konventionen",
#               "kind": "page"
#             },
#             {
#               "name": "Formatierungskonventionen",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Formatierungskonventionen",
#               "kind": "page"
#             },
#             {
#               "name": "Mathematische Konventionen",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Mathematische Konventionen",
#               "kind": "page"
#             },
#             {
#               "name": "Zitieren und Quellenangaben",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Zitieren und Quellenangaben",
#               "kind": "page"
#             },
#             {
#               "name": "Hinweise zu Lizenzen",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Hinweise zu Lizenzen",
#               "kind": "page"
#             }
#           ]
#         },
#         {
#           "name": "Medien erstellen",
#           "kind": "section",
#           "pages": [
#             {
#               "name": "Erstellen von Medien",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Erstellen von Medien",
#               "kind": "page"
#             }
#           ]
#         },
#         {
#           "name": "Bearbeiten der Projektstruktur",
#           "kind": "section",
#           "pages": [
#             {
#               "name": "Sitemap",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Sitemap",
#               "kind": "page"
#             },
#             {
#               "name": "Artikel erstellen",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Artikel erstellen",
#               "kind": "page"
#             },
#             {
#               "name": "Artikel umbenennen und l\u00f6schen",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Artikel umbenennen und l\u00f6schen",
#               "kind": "page"
#             },
#             {
#               "name": "Inhalte in den Abstellraum verschieben",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Inhalte in den Abstellraum verschieben",
#               "kind": "page"
#             }
#           ]
#         },
#         {
#           "name": "Wiki-Tools",
#           "kind": "section",
#           "pages": [
#             {
#               "name": "Volltextsuche",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Volltextsuche",
#               "kind": "page"
#             },
#             {
#               "name": "Beobachtungsliste",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Beobachtungsliste",
#               "kind": "page"
#             },
#             {
#               "name": "Linter",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Linter",
#               "kind": "page"
#             },
#             {
#               "name": "Banner",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Banner",
#               "kind": "page"
#             },
#             {
#               "name": "Zugriffszahlen messen",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Zugriffszahlen messen",
#               "kind": "page"
#             },
#             {
#               "name": "Letzte \u00c4nderungen am Projekt",
#               "href": "Spezial:\u00c4nderungen an verlinkten Seiten/Mathe f\u00fcr Nicht-Freaks: Sitemap",
#               "kind": "page"
#             }
#           ]
#         },
#         {
#           "name": "Printausgabe",
#           "kind": "section",
#           "pages": [
#             {
#               "name": "Spezifikation unserer Buchausgaben",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Print specification",
#               "kind": "page"
#             }
#           ]
#         },
#         {
#           "name": "Archiv",
#           "kind": "section",
#           "pages": [
#             {
#               "name": "Archiv",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Archiv",
#               "kind": "page"
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "name": "\u00dcber das Projekt",
#       "href": "Mathe f\u00fcr Nicht-Freaks: \u00dcber das Projekt",
#       "kind": "book",
#       "sections": [
#         {
#           "name": "Buchanf\u00e4nge",
#           "kind": "section",
#           "pages": [
#             {
#               "name": "\u00dcber das Projekt",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Projektbeschreibung",
#               "kind": "page"
#             },
#             {
#               "name": "Unterst\u00fctze uns!",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Unterst\u00fctze uns",
#               "kind": "page"
#             },
#             {
#               "name": "Kopiere uns!",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Kopiere uns",
#               "kind": "page"
#             },
#             {
#               "name": "Spenden",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Spenden",
#               "kind": "page"
#             },
#             {
#               "name": "Unsere didaktische Vision",
#               "href": "Mathe f\u00fcr Nicht-Freaks: Unsere didaktische Vision",
#               "kind": "page"
#             }
#           ]
#         }
#       ]
#     }
#   ]
# }
